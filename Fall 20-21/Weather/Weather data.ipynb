# %% [markdown]
# ## Scraping Weather Data

# %% [markdown]
# http://www.climate.psu.edu/data/city_information/index.php?city=phl&page=dwa&type=big7

# %%
#!pip install tabula-py

# %%
import tabula
import pandas as pd

# %%
# Convert all PDF Tables to own seperate CSV File
tabula.convert_into("Weather/2007.pdf","Weather Data/2007.csv", pages='all')
tabula.convert_into("Weather/2008.pdf","Weather Data/2008.csv", pages='all')
tabula.convert_into("Weather/2009.pdf","Weather Data/2009.csv", pages='all')
tabula.convert_into("Weather/2010.pdf","Weather Data/2010.csv", pages='all')
tabula.convert_into("Weather/2011.pdf","Weather Data/2011.csv", pages='all')
tabula.convert_into("Weather/2012.pdf","Weather Data/2012.csv", pages='all')
tabula.convert_into("Weather/2013.pdf","Weather Data/2013.csv", pages='all')
tabula.convert_into("Weather/2014.pdf","Weather Data/2014.csv", pages='all')
tabula.convert_into("Weather/2015.pdf","Weather Data/2015.csv", pages='all')
tabula.convert_into("Weather/2016.pdf","Weather Data/2016.csv", pages='all')
tabula.convert_into("Weather/2017.pdf","Weather Data/2017.csv", pages='all')
tabula.convert_into("Weather/2018.pdf","Weather Data/2018.csv", pages='all')

# %%
# combine tables

import glob

all_data = pd.DataFrame()
for f in sorted(glob.glob("Weather Data/*.csv")):
    print(f)
    df = pd.read_csv(f)
    all_data = all_data.append(df,ignore_index=True)
# Out:
# Weather Data/2007.csv
# Weather Data/2008.csv
# Weather Data/2009.csv
# Weather Data/2010.csv
# Weather Data/2011.csv
# Weather Data/2012.csv
# Weather Data/2013.csv
# Weather Data/2014.csv
# Weather Data/2015.csv
# Weather Data/2016.csv
# Weather Data/2017.csv
# Weather Data/2018.csv

# %%
# Drop NAs and irrelevant cols
all_data = all_data.dropna(subset=['Date'])
all_data = all_data[all_data.Date != "Date"]

# %%
all_data
# Out:
#             Date High Low Avg Temp HDD CDD GDD Avg.1 Avg.2 Avg.3 Avg.4  \
# 1     2007-12-31   47  33  39    5  26   0   0    31    73     9   240
# 2     2007-12-30   42  33  38    4  27   0   0    31    78     6   125
# 3     2007-12-29   52  39  48   14  17   0   0    38    73     9   262
# 4     2007-12-28   49  33  42    8  23   0   0    34    78     5   179
# 5     2007-12-27   45  37  39    4  26   0   0    36    86     6   207
# ...          ...  ...  ..  ..  ...  ..  ..  ..   ...   ...   ...   ...
# 4522      1/5/18   17  11  14  -19  51   0   0    -5    42    22   280
# 4523      1/4/18   28  16  23  -10  42   0   0    12    65    22   322
# 4524      1/3/18   31  14  23  -10  42   0   0     1    40     4   116
# 4525      1/2/18   24  13  19  -14  46   0   0     2    47    13   266
# 4526      1/1/18   19   7  14  -20  51   0   0    -3    46    11   288
#
#        Avg.5  Total # obs
# 1     1016.2   0.13    24
# 2     1018.6   0.18    24
# 3     1016.3   0.42    24
# 4     1025.5   0.14    24
# 5     1017.9  Trace    24
# ...      ...    ...   ...
# 4522  1015.4    NaN    24
# 4523  1002.4    0.1    20
# 4524  1025.5    NaN    21
# 4525  1031.2    NaN    24
# 4526  1030.7    NaN    24
#
# [4359 rows x 15 columns]

# %%
from datetime import datetime
from dateutil import parser

# function to format multiple dates - https://stackoverflow.com/questions/49608039/how-to-format-multiple-date-formats-into-single-date-in-python
def converter(lst):
    for i in lst:
        try:
            yield parser.parse(i)
        except ValueError:
            try:
                yield parser.parse(i, dayfirst=True)
            except ValueError:
                try:
                    yield datetime.strptime(i, '%Y-%d-%b')
                except:
                    yield i

res = list(converter(all_data.Date))

# %%
res
# Out:
# [datetime.datetime(2007, 12, 31, 0, 0),
#  datetime.datetime(2007, 12, 30, 0, 0),
#  datetime.datetime(2007, 12, 29, 0, 0),
#  datetime.datetime(2007, 12, 28, 0, 0),
#  datetime.datetime(2007, 12, 27, 0, 0),
#  datetime.datetime(2007, 12, 26, 0, 0),
#  datetime.datetime(2007, 12, 25, 0, 0),
#  datetime.datetime(2007, 12, 24, 0, 0),
#  datetime.datetime(2007, 12, 23, 0, 0),
#  datetime.datetime(2007, 12, 22, 0, 0),
#  datetime.datetime(2007, 12, 21, 0, 0),
#  datetime.datetime(2007, 12, 20, 0, 0),
#  datetime.datetime(2007, 12, 19, 0, 0),
#  datetime.datetime(2007, 12, 18, 0, 0),
#  datetime.datetime(2007, 12, 17, 0, 0),
#  datetime.datetime(2007, 12, 16, 0, 0),
#  datetime.datetime(2007, 12, 15, 0, 0),
#  datetime.datetime(2007, 12, 14, 0, 0),
#  datetime.datetime(2007, 12, 13, 0, 0),
#  datetime.datetime(2007, 12, 12, 0, 0),
#  datetime.datetime(2007, 12, 11, 0, 0),
#  datetime.datetime(2007, 12, 10, 0, 0),
#  datetime.datetime(2007, 12, 9, 0, 0),
#  datetime.datetime(2007, 12, 8, 0, 0),
#  datetime.datetime(2007, 12, 7, 0, 0),
#  datetime.datetime(2007, 12, 6, 0, 0),
#  datetime.datetime(2007, 12, 5, 0, 0),
#  datetime.datetime(2007, 12, 4, 0, 0),
#  datetime.datetime(2007, 12, 3, 0, 0),
#  datetime.datetime(2007, 12, 2, 0, 0),
#  datetime.datetime(2007, 12, 1, 0, 0),
#  datetime.datetime(2007, 11, 30, 0, 0),
#  datetime.datetime(2007, 11, 29, 0, 0),
#  datetime.datetime(2007, 11, 28, 0, 0),
#  datetime.datetime(2007, 11, 27, 0, 0),
#  datetime.datetime(2007, 11, 26, 0, 0),
#  datetime.datetime(2007, 11, 25, 0, 0),
#  datetime.datetime(2007, 11, 24, 0, 0),
#  datetime.datetime(2007, 11, 23, 0, 0),
#  datetime.datetime(2007, 11, 22, 0, 0),
#  datetime.datetime(2007, 11, 21, 0, 0),
#  datetime.datetime(2007, 11, 20, 0, 0),
#  datetime.datetime(2007, 11, 19, 0, 0),
#  datetime.datetime(2007, 11, 18, 0, 0),
#  datetime.datetime(2007, 11, 17, 0, 0),
#  datetime.datetime(2007, 11, 16, 0, 0),
#  datetime.datetime(2007, 11, 15, 0, 0),
#  datetime.datetime(2007, 11, 14, 0, 0),
#  datetime.datetime(2007, 11, 13, 0, 0),
#  datetime.datetime(2007, 11, 12, 0, 0),
#  datetime.datetime(2007, 11, 11, 0, 0),
#  datetime.datetime(2007, 11, 10, 0, 0),
#  datetime.datetime(2007, 11, 9, 0, 0),
#  datetime.datetime(2007, 11, 8, 0, 0),
#  datetime.datetime(2007, 11, 7, 0, 0),
#  datetime.datetime(2007, 11, 6, 0, 0),
#  datetime.datetime(2007, 11, 5, 0, 0),
#  datetime.datetime(2007, 11, 4, 0, 0),
#  datetime.datetime(2007, 11, 3, 0, 0),
#  datetime.datetime(2007, 11, 2, 0, 0),
#  datetime.datetime(2007, 11, 1, 0, 0),
#  datetime.datetime(2007, 10, 31, 0, 0),
#  datetime.datetime(2007, 10, 30, 0, 0),
#  datetime.datetime(2007, 10, 29, 0, 0),
#  datetime.datetime(2007, 10, 28, 0, 0),
#  datetime.datetime(2007, 10, 27, 0, 0),
#  datetime.datetime(2007, 10, 26, 0, 0),
#  datetime.datetime(2007, 10, 25, 0, 0),
#  datetime.datetime(2007, 10, 24, 0, 0),
#  datetime.datetime(2007, 10, 23, 0, 0),
#  datetime.datetime(2007, 10, 22, 0, 0),
#  datetime.datetime(2007, 10, 21, 0, 0),
#  datetime.datetime(2007, 10, 20, 0, 0),
#  datetime.datetime(2007, 10, 19, 0, 0),
#  datetime.datetime(2007, 10, 18, 0, 0),
#  datetime.datetime(2007, 10, 17, 0, 0),
#  datetime.datetime(2007, 10, 16, 0, 0),
#  datetime.datetime(2007, 10, 15, 0, 0),
#  datetime.datetime(2007, 10, 14, 0, 0),
#  datetime.datetime(2007, 10, 13, 0, 0),
#  datetime.datetime(2007, 10, 12, 0, 0),
#  datetime.datetime(2007, 10, 11, 0, 0),
#  datetime.datetime(2007, 10, 10, 0, 0),
#  datetime.datetime(2007, 10, 9, 0, 0),
#  datetime.datetime(2007, 10, 8, 0, 0),
#  datetime.datetime(2007, 10, 7, 0, 0),
#  datetime.datetime(2007, 10, 6, 0, 0),
#  datetime.datetime(2007, 10, 5, 0, 0),
#  datetime.datetime(2007, 10, 4, 0, 0),
#  datetime.datetime(2007, 10, 3, 0, 0),
#  datetime.datetime(2007, 10, 2, 0, 0),
#  datetime.datetime(2007, 10, 1, 0, 0),
#  datetime.datetime(2007, 9, 30, 0, 0),
#  datetime.datetime(2007, 9, 29, 0, 0),
#  datetime.datetime(2007, 9, 28, 0, 0),
#  datetime.datetime(2007, 9, 27, 0, 0),
#  datetime.datetime(2007, 9, 26, 0, 0),
#  datetime.datetime(2007, 9, 24, 0, 0),
#  datetime.datetime(2007, 9, 23, 0, 0),
#  datetime.datetime(2007, 9, 22, 0, 0),
#  datetime.datetime(2007, 9, 21, 0, 0),
#  datetime.datetime(2007, 9, 20, 0, 0),
#  datetime.datetime(2007, 9, 19, 0, 0),
#  datetime.datetime(2007, 9, 18, 0, 0),
#  datetime.datetime(2007, 9, 17, 0, 0),
#  datetime.datetime(2007, 9, 16, 0, 0),
#  datetime.datetime(2007, 9, 15, 0, 0),
#  datetime.datetime(2007, 9, 14, 0, 0),
#  datetime.datetime(2007, 9, 13, 0, 0),
#  datetime.datetime(2007, 9, 12, 0, 0),
#  datetime.datetime(2007, 9, 11, 0, 0),
#  datetime.datetime(2007, 9, 10, 0, 0),
#  datetime.datetime(2007, 9, 9, 0, 0),
#  datetime.datetime(2007, 9, 8, 0, 0),
#  datetime.datetime(2007, 9, 7, 0, 0),
#  datetime.datetime(2007, 9, 6, 0, 0),
#  datetime.datetime(2007, 9, 5, 0, 0),
#  datetime.datetime(2007, 9, 4, 0, 0),
#  datetime.datetime(2007, 9, 3, 0, 0),
#  datetime.datetime(2007, 9, 2, 0, 0),
#  datetime.datetime(2007, 9, 1, 0, 0),
#  datetime.datetime(2007, 8, 31, 0, 0),
#  datetime.datetime(2007, 8, 30, 0, 0),
#  datetime.datetime(2007, 8, 29, 0, 0),
#  datetime.datetime(2007, 8, 28, 0, 0),
#  datetime.datetime(2007, 8, 27, 0, 0),
#  datetime.datetime(2007, 8, 26, 0, 0),
#  datetime.datetime(2007, 8, 25, 0, 0),
#  datetime.datetime(2007, 8, 24, 0, 0),
#  datetime.datetime(2007, 8, 23, 0, 0),
#  datetime.datetime(2007, 8, 22, 0, 0),
#  datetime.datetime(2007, 8, 21, 0, 0),
#  datetime.datetime(2007, 8, 20, 0, 0),
#  datetime.datetime(2007, 8, 19, 0, 0),
#  datetime.datetime(2007, 8, 18, 0, 0),
#  datetime.datetime(2007, 8, 17, 0, 0),
#  datetime.datetime(2007, 8, 16, 0, 0),
#  datetime.datetime(2007, 8, 15, 0, 0),
#  datetime.datetime(2007, 8, 14, 0, 0),
#  datetime.datetime(2007, 8, 13, 0, 0),
#  datetime.datetime(2007, 8, 12, 0, 0),
#  datetime.datetime(2007, 8, 11, 0, 0),
#  datetime.datetime(2007, 8, 10, 0, 0),
#  datetime.datetime(2007, 8, 9, 0, 0),
#  datetime.datetime(2007, 8, 8, 0, 0),
#  datetime.datetime(2007, 8, 7, 0, 0),
#  datetime.datetime(2007, 8, 6, 0, 0),
#  datetime.datetime(2007, 8, 5, 0, 0),
#  datetime.datetime(2007, 8, 4, 0, 0),
#  datetime.datetime(2007, 8, 3, 0, 0),
#  datetime.datetime(2007, 8, 2, 0, 0),
#  datetime.datetime(2007, 8, 1, 0, 0),
#  datetime.datetime(2007, 7, 31, 0, 0),
#  datetime.datetime(2007, 7, 30, 0, 0),
#  datetime.datetime(2007, 7, 29, 0, 0),
#  datetime.datetime(2007, 7, 28, 0, 0),
#  datetime.datetime(2007, 7, 27, 0, 0),
#  datetime.datetime(2007, 7, 26, 0, 0),
#  datetime.datetime(2007, 7, 25, 0, 0),
#  datetime.datetime(2007, 7, 24, 0, 0),
#  datetime.datetime(2007, 7, 23, 0, 0),
#  datetime.datetime(2007, 7, 22, 0, 0),
#  datetime.datetime(2007, 7, 21, 0, 0),
#  datetime.datetime(2007, 7, 20, 0, 0),
#  datetime.datetime(2007, 7, 19, 0, 0),
#  datetime.datetime(2007, 7, 18, 0, 0),
#  datetime.datetime(2007, 7, 17, 0, 0),
#  datetime.datetime(2007, 7, 16, 0, 0),
#  datetime.datetime(2007, 7, 15, 0, 0),
#  datetime.datetime(2007, 7, 14, 0, 0),
#  datetime.datetime(2007, 7, 13, 0, 0),
#  datetime.datetime(2007, 7, 12, 0, 0),
#  datetime.datetime(2007, 7, 11, 0, 0),
#  datetime.datetime(2007, 7, 10, 0, 0),
#  datetime.datetime(2007, 7, 9, 0, 0),
#  datetime.datetime(2007, 7, 8, 0, 0),
#  datetime.datetime(2007, 7, 7, 0, 0),
#  datetime.datetime(2007, 7, 6, 0, 0),
#  datetime.datetime(2007, 7, 5, 0, 0),
#  datetime.datetime(2007, 7, 4, 0, 0),
#  datetime.datetime(2007, 7, 3, 0, 0),
#  datetime.datetime(2007, 7, 2, 0, 0),
#  datetime.datetime(2007, 7, 1, 0, 0),
#  datetime.datetime(2007, 6, 30, 0, 0),
#  datetime.datetime(2007, 6, 29, 0, 0),
#  datetime.datetime(2007, 6, 28, 0, 0),
#  datetime.datetime(2007, 6, 27, 0, 0),
#  datetime.datetime(2007, 6, 26, 0, 0),
#  datetime.datetime(2007, 6, 25, 0, 0),
#  datetime.datetime(2007, 6, 24, 0, 0),
#  datetime.datetime(2007, 6, 23, 0, 0),
#  datetime.datetime(2007, 6, 22, 0, 0),
#  datetime.datetime(2007, 6, 21, 0, 0),
#  datetime.datetime(2007, 6, 20, 0, 0),
#  datetime.datetime(2007, 6, 19, 0, 0),
#  datetime.datetime(2007, 6, 18, 0, 0),
#  datetime.datetime(2007, 6, 17, 0, 0),
#  datetime.datetime(2007, 6, 16, 0, 0),
#  datetime.datetime(2007, 6, 15, 0, 0),
#  datetime.datetime(2007, 6, 14, 0, 0),
#  datetime.datetime(2007, 6, 13, 0, 0),
#  datetime.datetime(2007, 6, 12, 0, 0),
#  datetime.datetime(2007, 6, 11, 0, 0),
#  datetime.datetime(2007, 6, 10, 0, 0),
#  datetime.datetime(2007, 6, 9, 0, 0),
#  datetime.datetime(2007, 6, 8, 0, 0),
#  datetime.datetime(2007, 6, 7, 0, 0),
#  datetime.datetime(2007, 6, 6, 0, 0),
#  datetime.datetime(2007, 6, 5, 0, 0),
#  datetime.datetime(2007, 6, 4, 0, 0),
#  datetime.datetime(2007, 6, 3, 0, 0),
#  datetime.datetime(2007, 6, 2, 0, 0),
#  datetime.datetime(2007, 6, 1, 0, 0),
#  datetime.datetime(2007, 5, 31, 0, 0),
#  datetime.datetime(2007, 5, 29, 0, 0),
#  datetime.datetime(2007, 5, 28, 0, 0),
#  datetime.datetime(2007, 5, 27, 0, 0),
#  datetime.datetime(2007, 5, 26, 0, 0),
#  datetime.datetime(2007, 5, 25, 0, 0),
#  datetime.datetime(2007, 5, 24, 0, 0),
#  datetime.datetime(2007, 5, 23, 0, 0),
#  datetime.datetime(2007, 5, 22, 0, 0),
#  datetime.datetime(2007, 5, 21, 0, 0),
#  datetime.datetime(2007, 5, 20, 0, 0),
#  datetime.datetime(2007, 5, 19, 0, 0),
#  datetime.datetime(2007, 5, 18, 0, 0),
#  datetime.datetime(2007, 5, 17, 0, 0),
#  datetime.datetime(2007, 5, 16, 0, 0),
#  datetime.datetime(2007, 5, 15, 0, 0),
#  datetime.datetime(2007, 5, 14, 0, 0),
#  datetime.datetime(2007, 5, 13, 0, 0),
#  datetime.datetime(2007, 5, 12, 0, 0),
#  datetime.datetime(2007, 5, 11, 0, 0),
#  datetime.datetime(2007, 5, 10, 0, 0),
#  datetime.datetime(2007, 5, 9, 0, 0),
#  datetime.datetime(2007, 5, 8, 0, 0),
#  datetime.datetime(2007, 5, 7, 0, 0),
#  datetime.datetime(2007, 5, 6, 0, 0),
#  datetime.datetime(2007, 5, 5, 0, 0),
#  datetime.datetime(2007, 5, 4, 0, 0),
#  datetime.datetime(2007, 5, 3, 0, 0),
#  datetime.datetime(2007, 5, 2, 0, 0),
#  datetime.datetime(2007, 5, 1, 0, 0),
#  datetime.datetime(2007, 4, 30, 0, 0),
#  datetime.datetime(2007, 4, 29, 0, 0),
#  datetime.datetime(2007, 4, 28, 0, 0),
#  datetime.datetime(2007, 4, 27, 0, 0),
#  datetime.datetime(2007, 4, 26, 0, 0),
#  datetime.datetime(2007, 4, 25, 0, 0),
#  datetime.datetime(2007, 4, 24, 0, 0),
#  datetime.datetime(2007, 4, 23, 0, 0),
#  datetime.datetime(2007, 4, 22, 0, 0),
#  datetime.datetime(2007, 4, 21, 0, 0),
#  datetime.datetime(2007, 4, 20, 0, 0),
#  datetime.datetime(2007, 4, 19, 0, 0),
#  datetime.datetime(2007, 4, 18, 0, 0),
#  datetime.datetime(2007, 4, 17, 0, 0),
#  datetime.datetime(2007, 4, 16, 0, 0),
#  datetime.datetime(2007, 4, 15, 0, 0),
#  datetime.datetime(2007, 4, 14, 0, 0),
#  datetime.datetime(2007, 4, 13, 0, 0),
#  datetime.datetime(2007, 4, 12, 0, 0),
#  datetime.datetime(2007, 4, 11, 0, 0),
#  datetime.datetime(2007, 4, 10, 0, 0),
#  datetime.datetime(2007, 4, 9, 0, 0),
#  datetime.datetime(2007, 4, 8, 0, 0),
#  datetime.datetime(2007, 4, 7, 0, 0),
#  datetime.datetime(2007, 4, 6, 0, 0),
#  datetime.datetime(2007, 4, 5, 0, 0),
#  datetime.datetime(2007, 4, 4, 0, 0),
#  datetime.datetime(2007, 4, 3, 0, 0),
#  datetime.datetime(2007, 4, 2, 0, 0),
#  datetime.datetime(2007, 4, 1, 0, 0),
#  datetime.datetime(2007, 3, 31, 0, 0),
#  datetime.datetime(2007, 3, 30, 0, 0),
#  datetime.datetime(2007, 3, 29, 0, 0),
#  datetime.datetime(2007, 3, 28, 0, 0),
#  datetime.datetime(2007, 3, 27, 0, 0),
#  datetime.datetime(2007, 3, 26, 0, 0),
#  datetime.datetime(2007, 3, 25, 0, 0),
#  datetime.datetime(2007, 3, 24, 0, 0),
#  datetime.datetime(2007, 3, 23, 0, 0),
#  datetime.datetime(2007, 3, 22, 0, 0),
#  datetime.datetime(2007, 3, 21, 0, 0),
#  datetime.datetime(2007, 3, 20, 0, 0),
#  datetime.datetime(2007, 3, 19, 0, 0),
#  datetime.datetime(2007, 3, 18, 0, 0),
#  datetime.datetime(2007, 3, 17, 0, 0),
#  datetime.datetime(2007, 3, 16, 0, 0),
#  datetime.datetime(2007, 3, 15, 0, 0),
#  datetime.datetime(2007, 3, 14, 0, 0),
#  datetime.datetime(2007, 3, 13, 0, 0),
#  datetime.datetime(2007, 3, 12, 0, 0),
#  datetime.datetime(2007, 3, 11, 0, 0),
#  datetime.datetime(2007, 3, 10, 0, 0),
#  datetime.datetime(2007, 3, 9, 0, 0),
#  datetime.datetime(2007, 3, 8, 0, 0),
#  datetime.datetime(2007, 3, 7, 0, 0),
#  datetime.datetime(2007, 3, 6, 0, 0),
#  datetime.datetime(2007, 3, 5, 0, 0),
#  datetime.datetime(2007, 3, 4, 0, 0),
#  datetime.datetime(2007, 3, 3, 0, 0),
#  datetime.datetime(2007, 3, 2, 0, 0),
#  datetime.datetime(2007, 3, 1, 0, 0),
#  datetime.datetime(2007, 2, 28, 0, 0),
#  datetime.datetime(2007, 2, 27, 0, 0),
#  datetime.datetime(2007, 2, 26, 0, 0),
#  datetime.datetime(2007, 2, 25, 0, 0),
#  datetime.datetime(2007, 2, 24, 0, 0),
#  datetime.datetime(2007, 2, 23, 0, 0),
#  datetime.datetime(2007, 2, 22, 0, 0),
#  datetime.datetime(2007, 2, 21, 0, 0),
#  datetime.datetime(2007, 2, 20, 0, 0),
#  datetime.datetime(2007, 2, 19, 0, 0),
#  datetime.datetime(2007, 2, 18, 0, 0),
#  datetime.datetime(2007, 2, 17, 0, 0),
#  datetime.datetime(2007, 2, 16, 0, 0),
#  datetime.datetime(2007, 2, 15, 0, 0),
#  datetime.datetime(2007, 2, 14, 0, 0),
#  datetime.datetime(2007, 2, 13, 0, 0),
#  datetime.datetime(2007, 2, 12, 0, 0),
#  datetime.datetime(2007, 2, 11, 0, 0),
#  datetime.datetime(2007, 2, 10, 0, 0),
#  datetime.datetime(2007, 2, 9, 0, 0),
#  datetime.datetime(2007, 2, 8, 0, 0),
#  datetime.datetime(2007, 2, 7, 0, 0),
#  datetime.datetime(2007, 2, 6, 0, 0),
#  datetime.datetime(2007, 2, 5, 0, 0),
#  datetime.datetime(2007, 2, 4, 0, 0),
#  datetime.datetime(2007, 2, 3, 0, 0),
#  datetime.datetime(2007, 2, 2, 0, 0),
#  datetime.datetime(2007, 2, 1, 0, 0),
#  datetime.datetime(2007, 1, 31, 0, 0),
#  datetime.datetime(2007, 1, 30, 0, 0),
#  datetime.datetime(2007, 1, 29, 0, 0),
#  datetime.datetime(2007, 1, 28, 0, 0),
#  datetime.datetime(2007, 1, 27, 0, 0),
#  datetime.datetime(2007, 1, 26, 0, 0),
#  datetime.datetime(2007, 1, 25, 0, 0),
#  datetime.datetime(2007, 1, 24, 0, 0),
#  datetime.datetime(2007, 1, 23, 0, 0),
#  datetime.datetime(2007, 1, 22, 0, 0),
#  datetime.datetime(2007, 1, 21, 0, 0),
#  datetime.datetime(2007, 1, 20, 0, 0),
#  datetime.datetime(2007, 1, 19, 0, 0),
#  datetime.datetime(2007, 1, 18, 0, 0),
#  datetime.datetime(2007, 1, 17, 0, 0),
#  datetime.datetime(2007, 1, 16, 0, 0),
#  datetime.datetime(2007, 1, 15, 0, 0),
#  datetime.datetime(2007, 1, 14, 0, 0),
#  datetime.datetime(2007, 1, 13, 0, 0),
#  datetime.datetime(2007, 1, 12, 0, 0),
#  datetime.datetime(2007, 1, 11, 0, 0),
#  datetime.datetime(2007, 1, 10, 0, 0),
#  datetime.datetime(2007, 1, 9, 0, 0),
#  datetime.datetime(2007, 1, 8, 0, 0),
#  datetime.datetime(2007, 1, 7, 0, 0),
#  datetime.datetime(2007, 1, 6, 0, 0),
#  datetime.datetime(2007, 1, 5, 0, 0),
#  datetime.datetime(2007, 1, 4, 0, 0),
#  datetime.datetime(2007, 1, 3, 0, 0),
#  datetime.datetime(2007, 1, 2, 0, 0),
#  datetime.datetime(2007, 1, 1, 0, 0),
#  datetime.datetime(2008, 12, 31, 0, 0),
#  datetime.datetime(2008, 12, 30, 0, 0),
#  datetime.datetime(2008, 12, 29, 0, 0),
#  datetime.datetime(2008, 12, 28, 0, 0),
#  datetime.datetime(2008, 12, 27, 0, 0),
#  datetime.datetime(2008, 12, 26, 0, 0),
#  datetime.datetime(2008, 12, 25, 0, 0),
#  datetime.datetime(2008, 12, 24, 0, 0),
#  datetime.datetime(2008, 12, 23, 0, 0),
#  datetime.datetime(2008, 12, 22, 0, 0),
#  datetime.datetime(2008, 12, 21, 0, 0),
#  datetime.datetime(2008, 12, 20, 0, 0),
#  datetime.datetime(2008, 12, 19, 0, 0),
#  datetime.datetime(2008, 12, 18, 0, 0),
#  datetime.datetime(2008, 12, 17, 0, 0),
#  datetime.datetime(2008, 12, 16, 0, 0),
#  datetime.datetime(2008, 12, 15, 0, 0),
#  datetime.datetime(2008, 12, 14, 0, 0),
#  datetime.datetime(2008, 12, 13, 0, 0),
#  datetime.datetime(2008, 12, 12, 0, 0),
#  datetime.datetime(2008, 12, 11, 0, 0),
#  datetime.datetime(2008, 12, 10, 0, 0),
#  datetime.datetime(2008, 12, 9, 0, 0),
#  datetime.datetime(2008, 12, 8, 0, 0),
#  datetime.datetime(2008, 12, 7, 0, 0),
#  datetime.datetime(2008, 12, 6, 0, 0),
#  datetime.datetime(2008, 12, 5, 0, 0),
#  datetime.datetime(2008, 12, 4, 0, 0),
#  datetime.datetime(2008, 12, 3, 0, 0),
#  datetime.datetime(2008, 12, 2, 0, 0),
#  datetime.datetime(2008, 12, 1, 0, 0),
#  datetime.datetime(2008, 11, 30, 0, 0),
#  datetime.datetime(2008, 11, 29, 0, 0),
#  datetime.datetime(2008, 11, 28, 0, 0),
#  datetime.datetime(2008, 11, 27, 0, 0),
#  datetime.datetime(2008, 11, 26, 0, 0),
#  datetime.datetime(2008, 11, 25, 0, 0),
#  datetime.datetime(2008, 11, 24, 0, 0),
#  datetime.datetime(2008, 11, 23, 0, 0),
#  datetime.datetime(2008, 11, 22, 0, 0),
#  datetime.datetime(2008, 11, 21, 0, 0),
#  datetime.datetime(2008, 11, 20, 0, 0),
#  datetime.datetime(2008, 11, 19, 0, 0),
#  datetime.datetime(2008, 11, 18, 0, 0),
#  datetime.datetime(2008, 11, 17, 0, 0),
#  datetime.datetime(2008, 11, 16, 0, 0),
#  datetime.datetime(2008, 11, 15, 0, 0),
#  datetime.datetime(2008, 11, 14, 0, 0),
#  datetime.datetime(2008, 11, 13, 0, 0),
#  datetime.datetime(2008, 11, 12, 0, 0),
#  datetime.datetime(2008, 11, 11, 0, 0),
#  datetime.datetime(2008, 11, 10, 0, 0),
#  datetime.datetime(2008, 11, 9, 0, 0),
#  datetime.datetime(2008, 11, 8, 0, 0),
#  datetime.datetime(2008, 11, 7, 0, 0),
#  datetime.datetime(2008, 11, 6, 0, 0),
#  datetime.datetime(2008, 11, 5, 0, 0),
#  datetime.datetime(2008, 11, 4, 0, 0),
#  datetime.datetime(2008, 11, 3, 0, 0),
#  datetime.datetime(2008, 11, 2, 0, 0),
#  datetime.datetime(2008, 11, 1, 0, 0),
#  datetime.datetime(2008, 10, 31, 0, 0),
#  datetime.datetime(2008, 10, 30, 0, 0),
#  datetime.datetime(2008, 10, 29, 0, 0),
#  datetime.datetime(2008, 10, 28, 0, 0),
#  datetime.datetime(2008, 10, 27, 0, 0),
#  datetime.datetime(2008, 10, 26, 0, 0),
#  datetime.datetime(2008, 10, 25, 0, 0),
#  datetime.datetime(2008, 10, 24, 0, 0),
#  datetime.datetime(2008, 10, 23, 0, 0),
#  datetime.datetime(2008, 10, 22, 0, 0),
#  datetime.datetime(2008, 10, 21, 0, 0),
#  datetime.datetime(2008, 10, 20, 0, 0),
#  datetime.datetime(2008, 10, 19, 0, 0),
#  datetime.datetime(2008, 10, 18, 0, 0),
#  datetime.datetime(2008, 10, 17, 0, 0),
#  datetime.datetime(2008, 10, 16, 0, 0),
#  datetime.datetime(2008, 10, 15, 0, 0),
#  datetime.datetime(2008, 10, 14, 0, 0),
#  datetime.datetime(2008, 10, 13, 0, 0),
#  datetime.datetime(2008, 10, 12, 0, 0),
#  datetime.datetime(2008, 10, 11, 0, 0),
#  datetime.datetime(2008, 10, 10, 0, 0),
#  datetime.datetime(2008, 10, 9, 0, 0),
#  datetime.datetime(2008, 10, 8, 0, 0),
#  datetime.datetime(2008, 10, 7, 0, 0),
#  datetime.datetime(2008, 10, 6, 0, 0),
#  datetime.datetime(2008, 10, 5, 0, 0),
#  datetime.datetime(2008, 10, 4, 0, 0),
#  datetime.datetime(2008, 10, 3, 0, 0),
#  datetime.datetime(2008, 10, 2, 0, 0),
#  datetime.datetime(2008, 10, 1, 0, 0),
#  datetime.datetime(2008, 9, 30, 0, 0),
#  datetime.datetime(2008, 9, 29, 0, 0),
#  datetime.datetime(2008, 9, 28, 0, 0),
#  datetime.datetime(2008, 9, 27, 0, 0),
#  datetime.datetime(2008, 9, 26, 0, 0),
#  datetime.datetime(2008, 9, 24, 0, 0),
#  datetime.datetime(2008, 9, 23, 0, 0),
#  datetime.datetime(2008, 9, 22, 0, 0),
#  datetime.datetime(2008, 9, 21, 0, 0),
#  datetime.datetime(2008, 9, 20, 0, 0),
#  datetime.datetime(2008, 9, 19, 0, 0),
#  datetime.datetime(2008, 9, 18, 0, 0),
#  datetime.datetime(2008, 9, 17, 0, 0),
#  datetime.datetime(2008, 9, 16, 0, 0),
#  datetime.datetime(2008, 9, 15, 0, 0),
#  datetime.datetime(2008, 9, 14, 0, 0),
#  datetime.datetime(2008, 9, 13, 0, 0),
#  datetime.datetime(2008, 9, 12, 0, 0),
#  datetime.datetime(2008, 9, 11, 0, 0),
#  datetime.datetime(2008, 9, 10, 0, 0),
#  datetime.datetime(2008, 9, 9, 0, 0),
#  datetime.datetime(2008, 9, 8, 0, 0),
#  datetime.datetime(2008, 9, 7, 0, 0),
#  datetime.datetime(2008, 9, 6, 0, 0),
#  datetime.datetime(2008, 9, 5, 0, 0),
#  datetime.datetime(2008, 9, 4, 0, 0),
#  datetime.datetime(2008, 9, 3, 0, 0),
#  datetime.datetime(2008, 9, 2, 0, 0),
#  datetime.datetime(2008, 9, 1, 0, 0),
#  datetime.datetime(2008, 8, 31, 0, 0),
#  datetime.datetime(2008, 8, 30, 0, 0),
#  datetime.datetime(2008, 8, 29, 0, 0),
#  datetime.datetime(2008, 8, 28, 0, 0),
#  datetime.datetime(2008, 8, 27, 0, 0),
#  datetime.datetime(2008, 8, 26, 0, 0),
#  datetime.datetime(2008, 8, 25, 0, 0),
#  datetime.datetime(2008, 8, 24, 0, 0),
#  datetime.datetime(2008, 8, 23, 0, 0),
#  datetime.datetime(2008, 8, 22, 0, 0),
#  datetime.datetime(2008, 8, 21, 0, 0),
#  datetime.datetime(2008, 8, 20, 0, 0),
#  datetime.datetime(2008, 8, 19, 0, 0),
#  datetime.datetime(2008, 8, 18, 0, 0),
#  datetime.datetime(2008, 8, 17, 0, 0),
#  datetime.datetime(2008, 8, 16, 0, 0),
#  datetime.datetime(2008, 8, 15, 0, 0),
#  datetime.datetime(2008, 8, 14, 0, 0),
#  datetime.datetime(2008, 8, 13, 0, 0),
#  datetime.datetime(2008, 8, 12, 0, 0),
#  datetime.datetime(2008, 8, 11, 0, 0),
#  datetime.datetime(2008, 8, 10, 0, 0),
#  datetime.datetime(2008, 8, 9, 0, 0),
#  datetime.datetime(2008, 8, 8, 0, 0),
#  datetime.datetime(2008, 8, 7, 0, 0),
#  datetime.datetime(2008, 8, 6, 0, 0),
#  datetime.datetime(2008, 8, 5, 0, 0),
#  datetime.datetime(2008, 8, 4, 0, 0),
#  datetime.datetime(2008, 8, 3, 0, 0),
#  datetime.datetime(2008, 8, 2, 0, 0),
#  datetime.datetime(2008, 8, 1, 0, 0),
#  datetime.datetime(2008, 7, 31, 0, 0),
#  datetime.datetime(2008, 7, 30, 0, 0),
#  datetime.datetime(2008, 7, 29, 0, 0),
#  datetime.datetime(2008, 7, 28, 0, 0),
#  datetime.datetime(2008, 7, 27, 0, 0),
#  datetime.datetime(2008, 7, 26, 0, 0),
#  datetime.datetime(2008, 7, 25, 0, 0),
#  datetime.datetime(2008, 7, 24, 0, 0),
#  datetime.datetime(2008, 7, 23, 0, 0),
#  datetime.datetime(2008, 7, 22, 0, 0),
#  datetime.datetime(2008, 7, 21, 0, 0),
#  datetime.datetime(2008, 7, 20, 0, 0),
#  datetime.datetime(2008, 7, 19, 0, 0),
#  datetime.datetime(2008, 7, 18, 0, 0),
#  datetime.datetime(2008, 7, 17, 0, 0),
#  datetime.datetime(2008, 7, 16, 0, 0),
#  datetime.datetime(2008, 7, 15, 0, 0),
#  datetime.datetime(2008, 7, 14, 0, 0),
#  datetime.datetime(2008, 7, 13, 0, 0),
#  datetime.datetime(2008, 7, 12, 0, 0),
#  datetime.datetime(2008, 7, 11, 0, 0),
#  datetime.datetime(2008, 7, 10, 0, 0),
#  datetime.datetime(2008, 7, 9, 0, 0),
#  datetime.datetime(2008, 7, 8, 0, 0),
#  datetime.datetime(2008, 7, 7, 0, 0),
#  datetime.datetime(2008, 7, 6, 0, 0),
#  datetime.datetime(2008, 7, 5, 0, 0),
#  datetime.datetime(2008, 7, 4, 0, 0),
#  datetime.datetime(2008, 7, 3, 0, 0),
#  datetime.datetime(2008, 7, 2, 0, 0),
#  datetime.datetime(2008, 7, 1, 0, 0),
#  datetime.datetime(2008, 6, 30, 0, 0),
#  datetime.datetime(2008, 6, 29, 0, 0),
#  datetime.datetime(2008, 6, 28, 0, 0),
#  datetime.datetime(2008, 6, 27, 0, 0),
#  datetime.datetime(2008, 6, 26, 0, 0),
#  datetime.datetime(2008, 6, 25, 0, 0),
#  datetime.datetime(2008, 6, 24, 0, 0),
#  datetime.datetime(2008, 6, 23, 0, 0),
#  datetime.datetime(2008, 6, 22, 0, 0),
#  datetime.datetime(2008, 6, 21, 0, 0),
#  datetime.datetime(2008, 6, 20, 0, 0),
#  datetime.datetime(2008, 6, 19, 0, 0),
#  datetime.datetime(2008, 6, 18, 0, 0),
#  datetime.datetime(2008, 6, 17, 0, 0),
#  datetime.datetime(2008, 6, 16, 0, 0),
#  datetime.datetime(2008, 6, 15, 0, 0),
#  datetime.datetime(2008, 6, 14, 0, 0),
#  datetime.datetime(2008, 6, 13, 0, 0),
#  datetime.datetime(2008, 6, 12, 0, 0),
#  datetime.datetime(2008, 6, 11, 0, 0),
#  datetime.datetime(2008, 6, 10, 0, 0),
#  datetime.datetime(2008, 6, 9, 0, 0),
#  datetime.datetime(2008, 6, 8, 0, 0),
#  datetime.datetime(2008, 6, 7, 0, 0),
#  datetime.datetime(2008, 6, 6, 0, 0),
#  datetime.datetime(2008, 6, 5, 0, 0),
#  datetime.datetime(2008, 6, 4, 0, 0),
#  datetime.datetime(2008, 6, 3, 0, 0),
#  datetime.datetime(2008, 6, 2, 0, 0),
#  datetime.datetime(2008, 6, 1, 0, 0),
#  datetime.datetime(2008, 5, 31, 0, 0),
#  datetime.datetime(2008, 5, 29, 0, 0),
#  datetime.datetime(2008, 5, 28, 0, 0),
#  datetime.datetime(2008, 5, 27, 0, 0),
#  datetime.datetime(2008, 5, 26, 0, 0),
#  datetime.datetime(2008, 5, 25, 0, 0),
#  datetime.datetime(2008, 5, 24, 0, 0),
#  datetime.datetime(2008, 5, 23, 0, 0),
#  datetime.datetime(2008, 5, 22, 0, 0),
#  datetime.datetime(2008, 5, 21, 0, 0),
#  datetime.datetime(2008, 5, 20, 0, 0),
#  datetime.datetime(2008, 5, 19, 0, 0),
#  datetime.datetime(2008, 5, 18, 0, 0),
#  datetime.datetime(2008, 5, 17, 0, 0),
#  datetime.datetime(2008, 5, 16, 0, 0),
#  datetime.datetime(2008, 5, 15, 0, 0),
#  datetime.datetime(2008, 5, 14, 0, 0),
#  datetime.datetime(2008, 5, 13, 0, 0),
#  datetime.datetime(2008, 5, 12, 0, 0),
#  datetime.datetime(2008, 5, 11, 0, 0),
#  datetime.datetime(2008, 5, 10, 0, 0),
#  datetime.datetime(2008, 5, 9, 0, 0),
#  datetime.datetime(2008, 5, 8, 0, 0),
#  datetime.datetime(2008, 5, 7, 0, 0),
#  datetime.datetime(2008, 5, 6, 0, 0),
#  datetime.datetime(2008, 5, 5, 0, 0),
#  datetime.datetime(2008, 5, 4, 0, 0),
#  datetime.datetime(2008, 5, 3, 0, 0),
#  datetime.datetime(2008, 5, 2, 0, 0),
#  datetime.datetime(2008, 5, 1, 0, 0),
#  datetime.datetime(2008, 4, 30, 0, 0),
#  datetime.datetime(2008, 4, 29, 0, 0),
#  datetime.datetime(2008, 4, 28, 0, 0),
#  datetime.datetime(2008, 4, 27, 0, 0),
#  datetime.datetime(2008, 4, 26, 0, 0),
#  datetime.datetime(2008, 4, 25, 0, 0),
#  datetime.datetime(2008, 4, 24, 0, 0),
#  datetime.datetime(2008, 4, 23, 0, 0),
#  datetime.datetime(2008, 4, 22, 0, 0),
#  datetime.datetime(2008, 4, 21, 0, 0),
#  datetime.datetime(2008, 4, 20, 0, 0),
#  datetime.datetime(2008, 4, 19, 0, 0),
#  datetime.datetime(2008, 4, 18, 0, 0),
#  datetime.datetime(2008, 4, 17, 0, 0),
#  datetime.datetime(2008, 4, 16, 0, 0),
#  datetime.datetime(2008, 4, 15, 0, 0),
#  datetime.datetime(2008, 4, 14, 0, 0),
#  datetime.datetime(2008, 4, 13, 0, 0),
#  datetime.datetime(2008, 4, 12, 0, 0),
#  datetime.datetime(2008, 4, 11, 0, 0),
#  datetime.datetime(2008, 4, 10, 0, 0),
#  datetime.datetime(2008, 4, 9, 0, 0),
#  datetime.datetime(2008, 4, 8, 0, 0),
#  datetime.datetime(2008, 4, 7, 0, 0),
#  datetime.datetime(2008, 4, 6, 0, 0),
#  datetime.datetime(2008, 4, 5, 0, 0),
#  datetime.datetime(2008, 4, 4, 0, 0),
#  datetime.datetime(2008, 4, 3, 0, 0),
#  datetime.datetime(2008, 4, 2, 0, 0),
#  datetime.datetime(2008, 4, 1, 0, 0),
#  datetime.datetime(2008, 3, 31, 0, 0),
#  datetime.datetime(2008, 3, 30, 0, 0),
#  datetime.datetime(2008, 3, 29, 0, 0),
#  datetime.datetime(2008, 3, 28, 0, 0),
#  datetime.datetime(2008, 3, 27, 0, 0),
#  datetime.datetime(2008, 3, 26, 0, 0),
#  datetime.datetime(2008, 3, 25, 0, 0),
#  datetime.datetime(2008, 3, 24, 0, 0),
#  datetime.datetime(2008, 3, 23, 0, 0),
#  datetime.datetime(2008, 3, 22, 0, 0),
#  datetime.datetime(2008, 3, 21, 0, 0),
#  datetime.datetime(2008, 3, 20, 0, 0),
#  datetime.datetime(2008, 3, 19, 0, 0),
#  datetime.datetime(2008, 3, 18, 0, 0),
#  datetime.datetime(2008, 3, 17, 0, 0),
#  datetime.datetime(2008, 3, 16, 0, 0),
#  datetime.datetime(2008, 3, 15, 0, 0),
#  datetime.datetime(2008, 3, 14, 0, 0),
#  datetime.datetime(2008, 3, 13, 0, 0),
#  datetime.datetime(2008, 3, 12, 0, 0),
#  datetime.datetime(2008, 3, 11, 0, 0),
#  datetime.datetime(2008, 3, 10, 0, 0),
#  datetime.datetime(2008, 3, 9, 0, 0),
#  datetime.datetime(2008, 3, 8, 0, 0),
#  datetime.datetime(2008, 3, 7, 0, 0),
#  datetime.datetime(2008, 3, 6, 0, 0),
#  datetime.datetime(2008, 3, 5, 0, 0),
#  datetime.datetime(2008, 3, 4, 0, 0),
#  datetime.datetime(2008, 3, 3, 0, 0),
#  datetime.datetime(2008, 3, 2, 0, 0),
#  datetime.datetime(2008, 3, 1, 0, 0),
#  datetime.datetime(2008, 2, 29, 0, 0),
#  datetime.datetime(2008, 2, 28, 0, 0),
#  datetime.datetime(2008, 2, 27, 0, 0),
#  datetime.datetime(2008, 2, 26, 0, 0),
#  datetime.datetime(2008, 2, 25, 0, 0),
#  datetime.datetime(2008, 2, 24, 0, 0),
#  datetime.datetime(2008, 2, 23, 0, 0),
#  datetime.datetime(2008, 2, 22, 0, 0),
#  datetime.datetime(2008, 2, 21, 0, 0),
#  datetime.datetime(2008, 2, 20, 0, 0),
#  datetime.datetime(2008, 2, 19, 0, 0),
#  datetime.datetime(2008, 2, 18, 0, 0),
#  datetime.datetime(2008, 2, 17, 0, 0),
#  datetime.datetime(2008, 2, 16, 0, 0),
#  datetime.datetime(2008, 2, 15, 0, 0),
#  datetime.datetime(2008, 2, 14, 0, 0),
#  datetime.datetime(2008, 2, 13, 0, 0),
#  datetime.datetime(2008, 2, 12, 0, 0),
#  datetime.datetime(2008, 2, 11, 0, 0),
#  datetime.datetime(2008, 2, 10, 0, 0),
#  datetime.datetime(2008, 2, 9, 0, 0),
#  datetime.datetime(2008, 2, 8, 0, 0),
#  datetime.datetime(2008, 2, 7, 0, 0),
#  datetime.datetime(2008, 2, 6, 0, 0),
#  datetime.datetime(2008, 2, 5, 0, 0),
#  datetime.datetime(2008, 2, 4, 0, 0),
#  datetime.datetime(2008, 2, 3, 0, 0),
#  datetime.datetime(2008, 2, 2, 0, 0),
#  datetime.datetime(2008, 2, 1, 0, 0),
#  datetime.datetime(2008, 1, 31, 0, 0),
#  datetime.datetime(2008, 1, 30, 0, 0),
#  datetime.datetime(2008, 1, 29, 0, 0),
#  datetime.datetime(2008, 1, 28, 0, 0),
#  datetime.datetime(2008, 1, 27, 0, 0),
#  datetime.datetime(2008, 1, 26, 0, 0),
#  datetime.datetime(2008, 1, 25, 0, 0),
#  datetime.datetime(2008, 1, 24, 0, 0),
#  datetime.datetime(2008, 1, 23, 0, 0),
#  datetime.datetime(2008, 1, 22, 0, 0),
#  datetime.datetime(2008, 1, 21, 0, 0),
#  datetime.datetime(2008, 1, 20, 0, 0),
#  datetime.datetime(2008, 1, 19, 0, 0),
#  datetime.datetime(2008, 1, 18, 0, 0),
#  datetime.datetime(2008, 1, 17, 0, 0),
#  datetime.datetime(2008, 1, 16, 0, 0),
#  datetime.datetime(2008, 1, 15, 0, 0),
#  datetime.datetime(2008, 1, 14, 0, 0),
#  datetime.datetime(2008, 1, 13, 0, 0),
#  datetime.datetime(2008, 1, 12, 0, 0),
#  datetime.datetime(2008, 1, 11, 0, 0),
#  datetime.datetime(2008, 1, 10, 0, 0),
#  datetime.datetime(2008, 1, 9, 0, 0),
#  datetime.datetime(2008, 1, 8, 0, 0),
#  datetime.datetime(2008, 1, 7, 0, 0),
#  datetime.datetime(2008, 1, 6, 0, 0),
#  datetime.datetime(2008, 1, 5, 0, 0),
#  datetime.datetime(2008, 1, 4, 0, 0),
#  datetime.datetime(2008, 1, 3, 0, 0),
#  datetime.datetime(2008, 1, 2, 0, 0),
#  datetime.datetime(2008, 1, 1, 0, 0),
#  datetime.datetime(2009, 12, 31, 0, 0),
#  datetime.datetime(2009, 12, 30, 0, 0),
#  datetime.datetime(2009, 12, 29, 0, 0),
#  datetime.datetime(2009, 12, 28, 0, 0),
#  datetime.datetime(2009, 12, 27, 0, 0),
#  datetime.datetime(2009, 12, 26, 0, 0),
#  datetime.datetime(2009, 12, 25, 0, 0),
#  datetime.datetime(2009, 12, 24, 0, 0),
#  datetime.datetime(2009, 12, 23, 0, 0),
#  datetime.datetime(2009, 12, 22, 0, 0),
#  datetime.datetime(2009, 12, 21, 0, 0),
#  datetime.datetime(2009, 12, 20, 0, 0),
#  datetime.datetime(2009, 12, 19, 0, 0),
#  datetime.datetime(2009, 12, 18, 0, 0),
#  datetime.datetime(2009, 12, 17, 0, 0),
#  datetime.datetime(2009, 12, 16, 0, 0),
#  datetime.datetime(2009, 12, 15, 0, 0),
#  datetime.datetime(2009, 12, 14, 0, 0),
#  datetime.datetime(2009, 12, 13, 0, 0),
#  datetime.datetime(2009, 12, 12, 0, 0),
#  datetime.datetime(2009, 12, 11, 0, 0),
#  datetime.datetime(2009, 12, 10, 0, 0),
#  datetime.datetime(2009, 12, 9, 0, 0),
#  datetime.datetime(2009, 12, 8, 0, 0),
#  datetime.datetime(2009, 12, 7, 0, 0),
#  datetime.datetime(2009, 12, 6, 0, 0),
#  datetime.datetime(2009, 12, 5, 0, 0),
#  datetime.datetime(2009, 12, 4, 0, 0),
#  datetime.datetime(2009, 12, 3, 0, 0),
#  datetime.datetime(2009, 12, 2, 0, 0),
#  datetime.datetime(2009, 12, 1, 0, 0),
#  datetime.datetime(2009, 11, 30, 0, 0),
#  datetime.datetime(2009, 11, 29, 0, 0),
#  datetime.datetime(2009, 11, 28, 0, 0),
#  datetime.datetime(2009, 11, 27, 0, 0),
#  datetime.datetime(2009, 11, 26, 0, 0),
#  datetime.datetime(2009, 11, 25, 0, 0),
#  datetime.datetime(2009, 11, 24, 0, 0),
#  datetime.datetime(2009, 11, 23, 0, 0),
#  datetime.datetime(2009, 11, 22, 0, 0),
#  datetime.datetime(2009, 11, 21, 0, 0),
#  datetime.datetime(2009, 11, 20, 0, 0),
#  datetime.datetime(2009, 11, 19, 0, 0),
#  datetime.datetime(2009, 11, 18, 0, 0),
#  datetime.datetime(2009, 11, 17, 0, 0),
#  datetime.datetime(2009, 11, 16, 0, 0),
#  datetime.datetime(2009, 11, 15, 0, 0),
#  datetime.datetime(2009, 11, 14, 0, 0),
#  datetime.datetime(2009, 11, 13, 0, 0),
#  datetime.datetime(2009, 11, 12, 0, 0),
#  datetime.datetime(2009, 11, 11, 0, 0),
#  datetime.datetime(2009, 11, 10, 0, 0),
#  datetime.datetime(2009, 11, 9, 0, 0),
#  datetime.datetime(2009, 11, 8, 0, 0),
#  datetime.datetime(2009, 11, 7, 0, 0),
#  datetime.datetime(2009, 11, 6, 0, 0),
#  datetime.datetime(2009, 11, 5, 0, 0),
#  datetime.datetime(2009, 11, 4, 0, 0),
#  datetime.datetime(2009, 11, 3, 0, 0),
#  datetime.datetime(2009, 11, 2, 0, 0),
#  datetime.datetime(2009, 11, 1, 0, 0),
#  datetime.datetime(2009, 10, 31, 0, 0),
#  datetime.datetime(2009, 10, 30, 0, 0),
#  datetime.datetime(2009, 10, 29, 0, 0),
#  datetime.datetime(2009, 10, 28, 0, 0),
#  datetime.datetime(2009, 10, 27, 0, 0),
#  datetime.datetime(2009, 10, 26, 0, 0),
#  datetime.datetime(2009, 10, 25, 0, 0),
#  datetime.datetime(2009, 10, 24, 0, 0),
#  datetime.datetime(2009, 10, 23, 0, 0),
#  datetime.datetime(2009, 10, 22, 0, 0),
#  datetime.datetime(2009, 10, 21, 0, 0),
#  datetime.datetime(2009, 10, 20, 0, 0),
#  datetime.datetime(2009, 10, 19, 0, 0),
#  datetime.datetime(2009, 10, 18, 0, 0),
#  datetime.datetime(2009, 10, 17, 0, 0),
#  datetime.datetime(2009, 10, 16, 0, 0),
#  datetime.datetime(2009, 10, 15, 0, 0),
#  datetime.datetime(2009, 10, 14, 0, 0),
#  datetime.datetime(2009, 10, 13, 0, 0),
#  datetime.datetime(2009, 10, 12, 0, 0),
#  datetime.datetime(2009, 10, 11, 0, 0),
#  datetime.datetime(2009, 10, 10, 0, 0),
#  datetime.datetime(2009, 10, 9, 0, 0),
#  datetime.datetime(2009, 10, 8, 0, 0),
#  datetime.datetime(2009, 10, 7, 0, 0),
#  datetime.datetime(2009, 10, 6, 0, 0),
#  datetime.datetime(2009, 10, 5, 0, 0),
#  datetime.datetime(2009, 10, 4, 0, 0),
#  datetime.datetime(2009, 10, 3, 0, 0),
#  datetime.datetime(2009, 10, 2, 0, 0),
#  datetime.datetime(2009, 10, 1, 0, 0),
#  datetime.datetime(2009, 9, 30, 0, 0),
#  datetime.datetime(2009, 9, 29, 0, 0),
#  datetime.datetime(2009, 9, 28, 0, 0),
#  datetime.datetime(2009, 9, 27, 0, 0),
#  datetime.datetime(2009, 9, 26, 0, 0),
#  datetime.datetime(2009, 9, 24, 0, 0),
#  datetime.datetime(2009, 9, 23, 0, 0),
#  datetime.datetime(2009, 9, 22, 0, 0),
#  datetime.datetime(2009, 9, 21, 0, 0),
#  datetime.datetime(2009, 9, 20, 0, 0),
#  datetime.datetime(2009, 9, 19, 0, 0),
#  datetime.datetime(2009, 9, 18, 0, 0),
#  datetime.datetime(2009, 9, 17, 0, 0),
#  datetime.datetime(2009, 9, 16, 0, 0),
#  datetime.datetime(2009, 9, 15, 0, 0),
#  datetime.datetime(2009, 9, 14, 0, 0),
#  datetime.datetime(2009, 9, 13, 0, 0),
#  datetime.datetime(2009, 9, 12, 0, 0),
#  datetime.datetime(2009, 9, 11, 0, 0),
#  datetime.datetime(2009, 9, 10, 0, 0),
#  datetime.datetime(2009, 9, 9, 0, 0),
#  datetime.datetime(2009, 9, 8, 0, 0),
#  datetime.datetime(2009, 9, 7, 0, 0),
#  datetime.datetime(2009, 9, 6, 0, 0),
#  datetime.datetime(2009, 9, 5, 0, 0),
#  datetime.datetime(2009, 9, 4, 0, 0),
#  datetime.datetime(2009, 9, 3, 0, 0),
#  datetime.datetime(2009, 9, 2, 0, 0),
#  datetime.datetime(2009, 9, 1, 0, 0),
#  datetime.datetime(2009, 8, 31, 0, 0),
#  datetime.datetime(2009, 8, 30, 0, 0),
#  datetime.datetime(2009, 8, 29, 0, 0),
#  datetime.datetime(2009, 8, 28, 0, 0),
#  datetime.datetime(2009, 8, 27, 0, 0),
#  datetime.datetime(2009, 8, 26, 0, 0),
#  datetime.datetime(2009, 8, 25, 0, 0),
#  datetime.datetime(2009, 8, 24, 0, 0),
#  datetime.datetime(2009, 8, 23, 0, 0),
#  datetime.datetime(2009, 8, 22, 0, 0),
#  datetime.datetime(2009, 8, 21, 0, 0),
#  datetime.datetime(2009, 8, 20, 0, 0),
#  datetime.datetime(2009, 8, 19, 0, 0),
#  datetime.datetime(2009, 8, 18, 0, 0),
#  datetime.datetime(2009, 8, 17, 0, 0),
#  datetime.datetime(2009, 8, 16, 0, 0),
#  datetime.datetime(2009, 8, 15, 0, 0),
#  datetime.datetime(2009, 8, 14, 0, 0),
#  datetime.datetime(2009, 8, 13, 0, 0),
#  datetime.datetime(2009, 8, 12, 0, 0),
#  datetime.datetime(2009, 8, 11, 0, 0),
#  datetime.datetime(2009, 8, 10, 0, 0),
#  datetime.datetime(2009, 8, 9, 0, 0),
#  datetime.datetime(2009, 8, 8, 0, 0),
#  datetime.datetime(2009, 8, 7, 0, 0),
#  datetime.datetime(2009, 8, 6, 0, 0),
#  datetime.datetime(2009, 8, 5, 0, 0),
#  datetime.datetime(2009, 8, 4, 0, 0),
#  datetime.datetime(2009, 8, 3, 0, 0),
#  datetime.datetime(2009, 8, 2, 0, 0),
#  datetime.datetime(2009, 8, 1, 0, 0),
#  datetime.datetime(2009, 7, 31, 0, 0),
#  datetime.datetime(2009, 7, 30, 0, 0),
#  datetime.datetime(2009, 7, 29, 0, 0),
#  datetime.datetime(2009, 7, 28, 0, 0),
#  datetime.datetime(2009, 7, 27, 0, 0),
#  datetime.datetime(2009, 7, 26, 0, 0),
#  datetime.datetime(2009, 7, 25, 0, 0),
#  datetime.datetime(2009, 7, 24, 0, 0),
#  datetime.datetime(2009, 7, 23, 0, 0),
#  datetime.datetime(2009, 7, 22, 0, 0),
#  datetime.datetime(2009, 7, 21, 0, 0),
#  datetime.datetime(2009, 7, 20, 0, 0),
#  datetime.datetime(2009, 7, 19, 0, 0),
#  datetime.datetime(2009, 7, 18, 0, 0),
#  datetime.datetime(2009, 7, 17, 0, 0),
#  datetime.datetime(2009, 7, 16, 0, 0),
#  datetime.datetime(2009, 7, 15, 0, 0),
#  datetime.datetime(2009, 7, 14, 0, 0),
#  datetime.datetime(2009, 7, 13, 0, 0),
#  datetime.datetime(2009, 7, 12, 0, 0),
#  datetime.datetime(2009, 7, 11, 0, 0),
#  datetime.datetime(2009, 7, 10, 0, 0),
#  datetime.datetime(2009, 7, 9, 0, 0),
#  datetime.datetime(2009, 7, 8, 0, 0),
#  datetime.datetime(2009, 7, 7, 0, 0),
#  datetime.datetime(2009, 7, 6, 0, 0),
#  datetime.datetime(2009, 7, 5, 0, 0),
#  datetime.datetime(2009, 7, 4, 0, 0),
#  datetime.datetime(2009, 7, 3, 0, 0),
#  datetime.datetime(2009, 7, 2, 0, 0),
#  datetime.datetime(2009, 7, 1, 0, 0),
#  datetime.datetime(2009, 6, 30, 0, 0),
#  datetime.datetime(2009, 6, 29, 0, 0),
#  datetime.datetime(2009, 6, 28, 0, 0),
#  datetime.datetime(2009, 6, 27, 0, 0),
#  datetime.datetime(2009, 6, 26, 0, 0),
#  datetime.datetime(2009, 6, 25, 0, 0),
#  datetime.datetime(2009, 6, 24, 0, 0),
#  datetime.datetime(2009, 6, 23, 0, 0),
#  datetime.datetime(2009, 6, 22, 0, 0),
#  datetime.datetime(2009, 6, 21, 0, 0),
#  datetime.datetime(2009, 6, 20, 0, 0),
#  datetime.datetime(2009, 6, 19, 0, 0),
#  datetime.datetime(2009, 6, 18, 0, 0),
#  datetime.datetime(2009, 6, 17, 0, 0),
#  datetime.datetime(2009, 6, 16, 0, 0),
#  datetime.datetime(2009, 6, 15, 0, 0),
#  datetime.datetime(2009, 6, 14, 0, 0),
#  datetime.datetime(2009, 6, 13, 0, 0),
#  datetime.datetime(2009, 6, 12, 0, 0),
#  datetime.datetime(2009, 6, 11, 0, 0),
#  datetime.datetime(2009, 6, 10, 0, 0),
#  datetime.datetime(2009, 6, 9, 0, 0),
#  datetime.datetime(2009, 6, 8, 0, 0),
#  datetime.datetime(2009, 6, 7, 0, 0),
#  datetime.datetime(2009, 6, 6, 0, 0),
#  datetime.datetime(2009, 6, 5, 0, 0),
#  datetime.datetime(2009, 6, 4, 0, 0),
#  datetime.datetime(2009, 6, 3, 0, 0),
#  datetime.datetime(2009, 6, 2, 0, 0),
#  datetime.datetime(2009, 6, 1, 0, 0),
#  datetime.datetime(2009, 5, 31, 0, 0),
#  datetime.datetime(2009, 5, 29, 0, 0),
#  datetime.datetime(2009, 5, 28, 0, 0),
#  datetime.datetime(2009, 5, 27, 0, 0),
#  datetime.datetime(2009, 5, 26, 0, 0),
#  datetime.datetime(2009, 5, 25, 0, 0),
#  datetime.datetime(2009, 5, 24, 0, 0),
#  datetime.datetime(2009, 5, 23, 0, 0),
#  datetime.datetime(2009, 5, 22, 0, 0),
#  datetime.datetime(2009, 5, 21, 0, 0),
#  datetime.datetime(2009, 5, 20, 0, 0),
#  datetime.datetime(2009, 5, 19, 0, 0),
#  datetime.datetime(2009, 5, 18, 0, 0),
#  datetime.datetime(2009, 5, 17, 0, 0),
#  datetime.datetime(2009, 5, 16, 0, 0),
#  datetime.datetime(2009, 5, 15, 0, 0),
#  datetime.datetime(2009, 5, 14, 0, 0),
#  datetime.datetime(2009, 5, 13, 0, 0),
#  datetime.datetime(2009, 5, 12, 0, 0),
#  datetime.datetime(2009, 5, 11, 0, 0),
#  datetime.datetime(2009, 5, 10, 0, 0),
#  datetime.datetime(2009, 5, 9, 0, 0),
#  datetime.datetime(2009, 5, 8, 0, 0),
#  datetime.datetime(2009, 5, 7, 0, 0),
#  datetime.datetime(2009, 5, 6, 0, 0),
#  datetime.datetime(2009, 5, 5, 0, 0),
#  datetime.datetime(2009, 5, 4, 0, 0),
#  datetime.datetime(2009, 5, 3, 0, 0),
#  datetime.datetime(2009, 5, 2, 0, 0),
#  datetime.datetime(2009, 5, 1, 0, 0),
#  datetime.datetime(2009, 4, 30, 0, 0),
#  datetime.datetime(2009, 4, 29, 0, 0),
#  datetime.datetime(2009, 4, 28, 0, 0),
#  datetime.datetime(2009, 4, 27, 0, 0),
#  datetime.datetime(2009, 4, 26, 0, 0),
#  datetime.datetime(2009, 4, 25, 0, 0),
#  datetime.datetime(2009, 4, 24, 0, 0),
#  datetime.datetime(2009, 4, 23, 0, 0),
#  datetime.datetime(2009, 4, 22, 0, 0),
#  datetime.datetime(2009, 4, 21, 0, 0),
#  datetime.datetime(2009, 4, 20, 0, 0),
#  datetime.datetime(2009, 4, 19, 0, 0),
#  datetime.datetime(2009, 4, 18, 0, 0),
#  datetime.datetime(2009, 4, 17, 0, 0),
#  datetime.datetime(2009, 4, 16, 0, 0),
#  datetime.datetime(2009, 4, 15, 0, 0),
#  datetime.datetime(2009, 4, 14, 0, 0),
#  datetime.datetime(2009, 4, 13, 0, 0),
#  datetime.datetime(2009, 4, 12, 0, 0),
#  datetime.datetime(2009, 4, 11, 0, 0),
#  datetime.datetime(2009, 4, 10, 0, 0),
#  datetime.datetime(2009, 4, 9, 0, 0),
#  datetime.datetime(2009, 4, 8, 0, 0),
#  datetime.datetime(2009, 4, 7, 0, 0),
#  datetime.datetime(2009, 4, 6, 0, 0),
#  datetime.datetime(2009, 4, 5, 0, 0),
#  datetime.datetime(2009, 4, 4, 0, 0),
#  datetime.datetime(2009, 4, 3, 0, 0),
#  datetime.datetime(2009, 4, 2, 0, 0),
#  datetime.datetime(2009, 4, 1, 0, 0),
#  ...]

# %%
# convert to format we want - YYYY/MM/DD
res_str = [i.strftime('%Y-%m-%d') for i in res]

# %%
all_data['Date'] = res_str

# %%
# sort the dates
all_data = all_data.sort_values(by=['Date'])

# %%
# view first 5 rows
all_data.head()
# Out:
#            Date High Low Avg Temp HDD CDD GDD Avg.1 Avg.2 Avg.3 Avg.4   Avg.5  \
# 376  2007-01-01   57  44  53   19  12   0   0    49    88     9   221  1012.0
# 375  2007-01-02   49  36  44   11  21   0   0    25    48    14   292  1023.1
# 374  2007-01-03   53  31  42    9  23   0   0    30    64     8   218  1028.1
# 373  2007-01-04   58  37  46   13  19   0   0    38    74     5   222  1022.0
# 372  2007-01-05   62  46  57   24   8   0   2    54    90     7   199  1014.4
#
#     Total # obs
# 376  1.12    24
# 375   NaN    24
# 374   NaN    24
# 373   NaN    24
# 372  0.14    24

# %%
# rename the columns
columns = ["Date", "High Temp.", "Low Temp.", "Avg Temp.", "Temp Departure",
           "HDD", "CDD", "GDD", "Avg Dewpoint", "Avg RH",
           "Avg Wind Speed", "Avg Wind Dir", "Avg Press",
           "Total Precip", "Num Observations"       
          ]

# %%
all_data.columns = columns

# %%
all_data.to_excel('all_weather_07_18.xlsx', index=None)
